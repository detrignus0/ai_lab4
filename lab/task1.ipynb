# %%
import pandas as pd

values = [5, 15, 25, 35, 45]
indices = ['a', 'b', 'c', 'd', 'e']

series = pd.Series(data=values, index=indices)

print("Созданный Series:")
print(series)

print("\nТип данных элементов Series:")
print(series.dtype)
# Out:
# Созданный Series:
# a     5
# b    15
# c    25
# d    35
# e    45
# dtype: int64
#
# Тип данных элементов Series:
# int64
