# %%
import numpy as np
import pandas as pd

random_values = np.random.randint(1, 101, size=50)
series = pd.Series(random_values)

print("Первые 7 элементов:")
print(series.head(7))

print("\nПоследние 5 элементов:")
print(series.tail(5))
# Out:
# Первые 7 элементов:
# 0    93
# 1     7
# 2    55
# 3    24
# 4    53
# 5    60
# 6     4
# dtype: int32
#
# Последние 5 элементов:
# 45    55
# 46    13
# 47    13
# 48    73
# 49    94
# dtype: int32
