# %%
import numpy as np
import pandas as pd

dates = pd.date_range(start="2024-03-01", periods=10, freq="D")
s3 = pd.Series(np.random.randint(10, 101, size=10), index=dates)
result_11 = s3.loc["2024-03-05":"2024-03-08"]
print(result_11)
# Out:
# 2024-03-05    22
# 2024-03-06    44
# 2024-03-07    26
# 2024-03-08    15
# Freq: D, dtype: int32
