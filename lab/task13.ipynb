# %%
import pandas as pd

s = pd.Series([100, 200, 300], index=["2024-03-10", "2024-03-11", "2024-03-12"])
s.index = pd.to_datetime(s.index)
print(s.index)
# Out:
# DatetimeIndex(['2024-03-10', '2024-03-11', '2024-03-12'], dtype='datetime64[us]', freq=None)
