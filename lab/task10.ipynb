# %%
import numpy as np
import pandas as pd

s2 = pd.Series(np.random.randint(50, 151, size=20))
print(s2.sum())
print(s2.mean())
print(s2.min())
print(s2.max())
print(s2.std())
# Out:
# 1736
# 86.8
# 53
# 146
# 31.7483526302837
