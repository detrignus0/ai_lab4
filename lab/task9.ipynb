# %%
import numpy as np
import pandas as pd

s1 = pd.Series([2, 4, 6, 8, 10])
result_9 = s1.apply(np.sqrt)
print(result_9)
# Out:
# 0    1.414214
# 1    2.000000
# 2    2.449490
# 3    2.828427
# 4    3.162278
# dtype: float64
