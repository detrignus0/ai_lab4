# %%
s1 = pd.Series([10, 20, 30, 40], index=['a', 'b', 'c', 'd'])
s2 = pd.Series([5, 15, 25, 35], index=['b', 'c', 'd', 'e'])

print("s1:")
print(s1)
print("\ns2:")
print(s2)

s_sum = s1 + s2
s_sum_filled = s_sum.fillna(0)
print("\nNaN возникает из-за несовпадения индексов: 'a' нет в s2, а 'e' нет в s1. При сложении числа с отсутствующим значением получается NaN.")
print(s_sum_filled)
# Out:
# s1:
# a    10
# b    20
# c    30
# d    40
# dtype: int64
#
# s2:
# b     5
# c    15
# d    25
# e    35
# dtype: int64
#
# NaN возникает из-за несовпадения индексов: 'a' нет в s2, а 'e' нет в s1. При сложении числа с отсутствующим значением получается NaN.
# a     0.0
# b    25.0
# c    45.0
# d    65.0
# e     0.0
# dtype: float64
