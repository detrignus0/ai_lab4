# %%
import pandas as pd

csv_data = """Дата,Цена
2024-03-01,100
2024-03-02,110
2024-03-03,105
2024-03-04,120
2024-03-05,115"""

with open("data.csv", "w", encoding="utf-8") as f:
    f.write(csv_data)

df = pd.read_csv("data.csv", index_col="Дата")
s = df["Цена"]
print(s)
# Out:
# Дата
# 2024-03-01    100
# 2024-03-02    110
# 2024-03-03    105
# 2024-03-04    120
# 2024-03-05    115
# Name: Цена, dtype: int64
